# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        print("Left half:", left_half)
        right_half = arr[mid:]
        print("Right half:", right_half)

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            print(f' left half: {left_half} right half: {right_half}')
            print('left half i:', left_half[i])
            print('right half j:', right_half[j])

            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
                print(f'i: {i} j: {j} k: {k} arr: {arr}')
            else:
                arr[k] = right_half[j]
                j += 1
                print(f'i: {i} j: {j} k: {k} arr: {arr}')

            k += 1
            print(f'i: {i} j: {j} k: {k} arr: {arr}')
            #print('arr:', arr)

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1
            print(f'i: {i} j: {j} k: {k} arr: {arr}')

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
            print(f'i: {i} j: {j} k: {k} arr: {arr}')
    print(f'arr: {arr}')
    return arr

# Example array
arr = [38, 27, 43, 3, 9, 82, 10, 15]
print("Original Array:", arr)

sorted_arr = merge_sort(arr)
print("Sorted Array:", sorted_arr)
# Out:
# Original Array: [38, 27, 43, 3, 9, 82, 10, 15]
# Left half: [38, 27, 43, 3]
# Right half: [9, 82, 10, 15]
# Left half: [38, 27]
# Right half: [43, 3]
# Left half: [38]
# Right half: [27]
# arr: [38]
# arr: [27]
# i: 0 j: 1 k: 0 arr: [27, 27]
# i: 0 j: 1 k: 1 arr: [27, 27]
# i: 1 j: 1 k: 2 arr: [27, 38]
# arr: [27, 38]
# Left half: [43]
# Right half: [3]
# arr: [43]
# arr: [3]
# i: 0 j: 1 k: 0 arr: [3, 3]
# i: 0 j: 1 k: 1 arr: [3, 3]
# i: 1 j: 1 k: 2 arr: [3, 43]
# arr: [3, 43]
# i: 0 j: 1 k: 0 arr: [3, 27, 43, 3]
# i: 0 j: 1 k: 1 arr: [3, 27, 43, 3]
# i: 1 j: 1 k: 1 arr: [3, 27, 43, 3]
# i: 1 j: 1 k: 2 arr: [3, 27, 43, 3]
# i: 2 j: 1 k: 2 arr: [3, 27, 38, 3]
# i: 2 j: 1 k: 3 arr: [3, 27, 38, 3]
# i: 2 j: 2 k: 4 arr: [3, 27, 38, 43]
# arr: [3, 27, 38, 43]
# Left half: [9, 82]
# Right half: [10, 15]
# Left half: [9]
# Right half: [82]
# arr: [9]
# arr: [82]
# i: 1 j: 0 k: 0 arr: [9, 82]
# i: 1 j: 0 k: 1 arr: [9, 82]
# i: 1 j: 1 k: 2 arr: [9, 82]
# arr: [9, 82]
# Left half: [10]
# Right half: [15]
# arr: [10]
# arr: [15]
# i: 1 j: 0 k: 0 arr: [10, 15]
# i: 1 j: 0 k: 1 arr: [10, 15]
# i: 1 j: 1 k: 2 arr: [10, 15]
# arr: [10, 15]
# i: 1 j: 0 k: 0 arr: [9, 82, 10, 15]
# i: 1 j: 0 k: 1 arr: [9, 82, 10, 15]
# i: 1 j: 1 k: 1 arr: [9, 10, 10, 15]
# i: 1 j: 1 k: 2 arr: [9, 10, 10, 15]
# i: 1 j: 2 k: 2 arr: [9, 10, 15, 15]
# i: 1 j: 2 k: 3 arr: [9, 10, 15, 15]
# i: 2 j: 2 k: 4 arr: [9, 10, 15, 82]
# arr: [9, 10, 15, 82]
# i: 1 j: 0 k: 0 arr: [3, 27, 43, 3, 9, 82, 10, 15]
# i: 1 j: 0 k: 1 arr: [3, 27, 43, 3, 9, 82, 10, 15]
# i: 1 j: 1 k: 1 arr: [3, 9, 43, 3, 9, 82, 10, 15]
# i: 1 j: 1 k: 2 arr: [3, 9, 43, 3, 9, 82, 10, 15]
# i: 1 j: 2 k: 2 arr: [3, 9, 10, 3, 9, 82, 10, 15]
# i: 1 j: 2 k: 3 arr: [3, 9, 10, 3, 9, 82, 10, 15]
# i: 1 j: 3 k: 3 arr: [3, 9, 10, 15, 9, 82, 10, 15]
# i: 1 j: 3 k: 4 arr: [3, 9, 10, 15, 9, 82, 10, 15]
# i: 2 j: 3 k: 4 arr: [3, 9, 10, 15, 27, 82, 10, 15]
# i: 2 j: 3 k: 5 arr: [3, 9, 10, 15, 27, 82, 10, 15]
# i: 3 j: 3 k: 5 arr: [3, 9, 10, 15, 27, 38, 10, 15]
# i: 3 j: 3 k: 6 arr: [3, 9, 10, 15, 27, 38, 10, 15]
# i: 4 j: 3 k: 6 arr: [3, 9, 10, 15, 27, 38, 43, 15]
# i: 4 j: 3 k: 7 arr: [3, 9, 10, 15, 27, 38, 43, 15]
# i: 4 j: 4 k: 8 arr: [3, 9, 10, 15, 27, 38, 43, 82]
# arr: [3, 9, 10, 15, 27, 38, 43, 82]
# Sorted Array: [3, 9, 10, 15, 27, 38, 43, 82]
